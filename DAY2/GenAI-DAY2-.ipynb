# %%
'''
ollama run <llm-modelName>
|
>>> what is AI?
....
....
---------------------------//Commandline 
'''

from langchain_ollama import OllamaLLM
print(OllamaLLM)
# Out:
# <class 'langchain_ollama.llms.OllamaLLM'>

# %%
from langchain_ollama import OllamaLLM
llm_obj = OllamaLLM(model='modelName')
llm_obj.invoke('UserQuery') ->llm_response //

# %%
from langchain_ollama import OllamaLLM
llm_obj = OllamaLLM(model='gemma2:2b')

# %%
response = llm_obj.invoke('what is GenAI llm explain in two lines?')

# %%
print(type(response),len(response))
# Out:
# <class 'str'> 202

# %%
print(response)
# Out:
# GenAI refers to Large Language Models (LLMs) trained on vast datasets to generate human-like text. These models excel at tasks like writing stories, translating languages, and summarizing information.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\karth'

# %%
# opc@hostname~]$ wget https://github.com/Palanikarthikeyan/GenAI_April_2026/blob/main/DAY1/requirements.txt
#
# ! pip install -r requirements.txt

# %%
! hostname
# Out:
# paka

# %% [raw]
# from langchain_ollama import OllamaLLM
# llm_obj = OllamaLLM(model="gemma2:2b")
# response = llm_obj.invoke("What is langchain?")
# print(response)

# %%
from langchain_ollama import OllamaLLM

# %%
llm_obj = OllamaLLM(model="gemma2:2b")

# %%
response = llm_obj.invoke("What is langchain?")

# %%
print(response)
# Out:
# LangChain is a powerful framework designed to simplify the development of applications powered by large language models (LLMs) like ChatGPT.
#
# Here's a breakdown of what LangChain offers and why it's significant:
#
# **What LangChain Does:**
#
# * **Modular Components:**  It provides pre-built components for building complex LLM applications, eliminating the need to build everything from scratch. These components include tools for:
#     * **Memory:**  Storing context and previous interactions (think of how your chat history remembers past conversations).
#     * **Prompt Templates:**  Creating customized input prompts for LLMs that guide their responses in specific ways.
#     * **Chain:**  Connecting multiple LLM calls together to perform complex tasks, like summarizing information or writing different types of content.
#     * **Indexes:**  Searching and accessing large amounts of data relevant to your application (like a library).
#
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
chat_prompt = ChatPromptTemplate([('system','Your are helpful AI assistant'),('user','Question:{question}')])

# %%
chain = chat_prompt | llm_obj
chain.invoke({'question':'what is langchain?'})
# Out:
# "LangChain is a powerful framework designed to streamline the development of applications powered by large language models (LLMs). \n\n**Here's a breakdown of LangChain's key aspects:**\n\n**1. Simplifies LLM Integration:** It provides tools and functions that make it much easier to connect LLMs like ChatGPT, Bard, etc., to other systems and data sources. This integration allows you to build applications that can understand, interpret, and act on complex information from various inputs.\n\n**2.  Flexible Data Handling:** LangChain enables the inclusion of different types of data within your LLM-powered applications: \n    * **Text**: Documents, articles, code\n    * **Images**: Visual understanding through image processing APIs\n    * **Databases**: Accessing and interacting with relational or NoSQL databases\n    * **APIs**: Integrating external services like weather forecasts, news feeds, and other data sources.\n\n**3. Extensible Architecture:** LangChain allows you to build custo
# ...

# %%
chat_prompt = ChatPromptTemplate([('system',"Say I don't Know"),('user','Question:{question}')])
chain = chat_prompt | llm_obj
chain.invoke({'question':'what is langchain?'})
# Out:
# "I don't know. \n\n**What is LangChain?**\n\nLangChain is an open-source framework designed to simplify the development of applications that utilize large language models (LLMs) like ChatGPT and Bard. It provides tools for chaining together different components, allowing developers to build more complex and sophisticated AI-powered systems.  \n"
