# %%
import matplotlib.pyplot as plt

#plt.plot([1,2,3],[15,17,35],marker='o')
plt.scatter([1,2,3],[15,17,35])
plt.grid(True)
plt.text(1,15,"Computer")
plt.text(1,17,"Laptop")
plt.text(3,35,"home")
# Out:
# Text(3, 35, 'home')

# %%
! pip show langchain
# Out:
# Name: langchain
# Version: 1.2.7
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\ProgramData\anaconda3\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by: langchain-tavily
# WARNING: Ignoring invalid distribution ~angchain-community (C:\ProgramData\anaconda3\Lib\site-packages)

# %%
! pip show oracledb
# Out:
# Name: oracledb
# Version: 3.3.0
# Summary: Python interface to Oracle Database
# Home-page: https://oracle.github.io/python-oracledb
# Author:
# Author-email: Anthony Tuininga <anthony.tuininga@oracle.com>
# License-Expression: UPL-1.0 OR Apache-2.0
# Location: C:\ProgramData\anaconda3\Lib\site-packages
# Requires: cryptography
# Required-by:
# WARNING: Ignoring invalid distribution ~angchain-community (C:\ProgramData\anaconda3\Lib\site-packages)

# %%
! pip show langchain-classic
# Out:
# Name: langchain-classic
# Version: 1.0.1
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\ProgramData\anaconda3\Lib\site-packages
# Requires: langchain-core, langchain-text-splitters, langsmith, pydantic, pyyaml, requests, sqlalchemy
# Required-by: langchain-community
# WARNING: Ignoring invalid distribution ~angchain-community (C:\ProgramData\anaconda3\Lib\site-packages)

# %%
import oracledb
connection = oracledb.connect(user="student",password="apelix",dsn="localhost:1521/FREEPDB1")

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-MiniLM-L6-v2")

# %%
from langchain_community.vectorstores import OracleVS

# Create DB connection 
# Done - cell Number 11

# Initialize Oracle Vector store
vector_store = OracleVS(client = connection,table_name = "demo3", embedding_function=embeddings)

# %%
text = ["oralce 23 ai supports vector search","Langchain is framework","Flask is webframework"] ## normal list content - not Document object

# %% [raw]
# vector_store.add_texts(text)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\karth'

# %%
os.chdir("Streamlit-Examples/")

# %%
! streamlit run p2.py
# Out:
# ^C

# %%
! streamlit run p7.py
# Out:
# ^C

# %%
! streamlit run PDF_RAG_app.py
# Out:
# ^C

# %%
os.chdir("..")

# %%
! streamlit run linearRegression_strem.py
# Out:
# ^C

# %%
##############################################################################
